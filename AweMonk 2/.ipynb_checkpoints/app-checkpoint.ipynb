# %%
from flask import *
import pandas as pd
import json
from scipy.stats import mode
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib
matplotlib.use('Agg')
from io import BytesIO
import base64
import pickle
import numpy as np

# %matplotlib inline

app = Flask(__name__)

@app.route('/', methods=['GET', 'POST'])
def login():
    error = None
    if request.method == 'POST':
        if request.form['username'] != 'admin' or request.form['password'] != 'admin@123':
            error = 'Invalid Credentials. Please try again.'
        else:
            return redirect(url_for('home'))
    return render_template('login.html', error=error)

@app.route('/newpatient',methods=['GET', 'POST'])
def newpatient():
    return render_template('Newpatient.html')
 
    
def diapredict(val,dic):
    model = pickle.load(open('diabetes.pkl','rb'))
    values = np.asarray(val)
    diamodel=model.predict(values.reshape(1, -1))[0]

    val=1
    if diamodel == 2 :
        msg="No Risk"
        val=1
    elif diamodel == 1 :
        msg="Early stage"
        val=2
    else:
        msg="Critical"
        val=4

    return val, msg

   
def copdpredict(val,dic):
    model = pickle.load(open('copd.pkl','rb'))
    values = np.asarray(val)
    copdmodel=model.predict(values.reshape(1, -1))[0]
    
    val=1
    if copdmodel == 2 :
        msg="No Risk"
        val=1
    elif copdmodel == 1 :
        msg="Early stage"
        val=2
    else:
        msg="Critical"
        val=4

    return val, msg
    
def ckdpredict(val,dic):
    model = pickle.load(open('ckd.pkl','rb'))
    values = np.asarray(val)
    ckdmodel=model.predict(values.reshape(1, -1))[0]
    val=1
    if ckdmodel == 2 :
        msg="No Risk"
        val=1
    elif ckdmodel == 1 :
        msg="Early stage"
        val=2
    else:
        msg="Critical"
        val=4

    return val, msg


def cadpredict(val,dic):
    model = pickle.load(open('cad.pkl','rb'))
    values = np.asarray(val)
    cadmodel=model.predict(values.reshape(1, -1))[0]
    
    val=1
    if cadmodel == 2 :
        msg="No Risk"
        val=1
    elif cadmodel == 1 :
        msg="Early stage"
        val=2
    else:
        msg="Critical"
        val=4

    return val, msg
    
def hyperpredict(val,dic):
    model = pickle.load(open('hypertension.pkl','rb'))
    values = np.asarray(val)
    hypermodel=model.predict(values.reshape(1, -1))[0]

    val=1
    if hypermodel == 2 :
        msg="No Risk"
        val=1
    elif hypermodel == 1 :
        msg="Early stage"
        val=2
    else:
        msg="Critical"
        val=4

    return val, msg
    
    
@app.route("/predict", methods = ['POST', 'GET'])
def predictPage():
        if request.method == 'POST':
            to_predict_dict = request.form.to_dict()
            
            # to_predict_list = list(map(float, list(to_predict_dict.values())))

            to_predict_list = []
            patient_id = ""
            gender = ""
            treated = ""
            race = ""
            age = ""
            for key, val in list(to_predict_dict.items()):

                try:
                    float(val)
                    to_predict_list.append(val)
                    if key == "Age":
                        age = val
                except:
                    if key == "Gender":
                        gender = val
                    if key == "Treated":
                        treated = val
                    if key == "Race":
                        race = val
                    if key == "":
                        patient_id = val

            
            diab_val,diab_msg = diapredict(to_predict_list,to_predict_dict)
            copd_val, copd_msg=copdpredict(to_predict_list,to_predict_dict)
            ckd_val, ckd_msg=ckdpredict(to_predict_list,to_predict_dict)
            cad_val, cad_msg=cadpredict(to_predict_list,to_predict_dict)
            hyper_val,hyper_msg=hyperpredict(to_predict_list,to_predict_dict)

            # return render_template('predict.html', diapred=diapred,copdpred=copdpred,ckdpred=ckdpred,cadpred=cadpred,hyperpred=hyperpred)    
            return render_template("PatientDetails.html",
            age=age,
            gender= "Female" if gender == "F" else "Male",
            treated=treated,
            race=race,
            patient_id=race,
            copd_val=copd_val,
            copd_msg=copd_msg,

            diab_val=diab_val,
            diab_msg=diab_msg,

            ckd_val=ckd_val,
            ckd_msg=ckd_msg,

            cad_val=cad_val,
            cad_msg=cad_msg,

            hyper_val=hyper_val,
            hyper_msg=hyper_msg
        )               

@app.route('/home')

def home():
    return render_template('Homepage.html')

filename = 'Data.csv'
data = pd.read_csv(filename)

@app.route('/GetPatientDetails/<int:userid>',methods = ['POST','GET'])
def GetPatientDetails(userid):
    if request.method == 'GET':
        patdetails=pd.DataFrame(data.loc[data["desy_sort_key"]==userid] [['desy_sort_key','gender_id','Age']]).to_dict('records')
        userdetails=json.dumps(patdetails)
        details=pd.DataFrame(data.loc[data["desy_sort_key"]==userid] )
        details=details.drop(columns=['desy_sort_key','gender_id','DiseaseType','race','Treated','Unnamed: 0'],axis=1).to_dict('records')
        patientcomponent=list(details[0].values())
        patientcomponents=json.dumps(patientcomponent)
        
        return redirect(url_for('DisplayPatientDetails',userdetails=userdetails,patientcomponents=patientcomponents))
  
    
@app.route('/fetchPatientParams/<int:userid>',methods = ['GET'])
def fetchPatientParams(userid):
    if request.method == 'GET':
        patdetails=pd.DataFrame(data.loc[data["desy_sort_key"]==userid] [['desy_sort_key','gender_id','Age']]).to_dict('records')
        userdetails=json.dumps(patdetails)
        details=pd.DataFrame(data.loc[data["desy_sort_key"]==userid] )
        details=details.drop(columns=['desy_sort_key','Unnamed: 0'],axis=1).to_dict('records')
        return details[0]
  
           
        
@app.route('/usersearch',methods = ['POST','GET'])  
def usersearch():
    if request.method == 'POST':
        userid=request.form["patientid"]
        return redirect(url_for('GetPatientDetails',userid=userid))
        
 
@app.route('/DisplayPatientDetails/<userdetails>/<patientcomponents>',methods = ['POST','GET'])
def DisplayPatientDetails(userdetails,patientcomponents):
    if request.method == 'GET':
        usd=json.loads(userdetails)
        patcomponents=json.loads(patientcomponents)
        model = pickle.load(open('copd.pkl','rb'))
        values = np.asarray(patcomponents)
        copdmodel=model.predict(values.reshape(1, -1))[0]
        if copdmodel == 2 :
            msg="No Risk"
        elif copdmodel == 1 :
            msg="Early stage"
        else:
            msg="Critical"
        model = pickle.load(open('diabetes.pkl','rb'))
        values = np.asarray(patcomponents)
        diamodel=model.predict(values.reshape(1, -1))[0]
        if diamodel == 2 :
            msg1="No Risk"
        elif diamodel == 1 :
            msg1="Early stage"
        else:
            msg1="Critical"
        model = pickle.load(open('hypertension.pkl','rb'))
        values = np.asarray(patcomponents)
        hypermodel=model.predict(values.reshape(1, -1))[0]
        if hypermodel == 2 :
            msg2="No Risk"
        elif hypermodel == 1 :
            msg2="Early stage"
        else:
            msg2="Critical"
        model = pickle.load(open('ckd.pkl','rb'))
        values = np.asarray(patcomponents)
        ckdmodel=model.predict(values.reshape(1, -1))[0]
        if ckdmodel == 2 :
            msg3="No Risk"
        elif ckdmodel == 1 :
            msg3="Early stage"
        else:
            msg3="Critical"
        model = pickle.load(open('cad.pkl','rb'))
        values = np.asarray(patcomponents)
        cadmodel=model.predict(values.reshape(1, -1))[0]
        if cadmodel == 2 :
            msg4="No Risk"
        elif cadmodel == 1 :
            msg4="Early stage"
        else:
            msg4="Critical"
    return render_template("PatientDetails.html",usd=usd,msg=msg,msg1=msg1,msg2=msg2,msg3=msg3,msg4=msg4)


@app.route('/appointments',methods=['GET', 'POST'])
def appointments():
    return render_template('appointments.html')


if __name__ =='__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/css/style2.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/css/font-awesome.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/js/popper.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/js/jquery-3.2.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/js/bootstrap.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/js/app.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:38] "GET /static/img/logo-dark.png HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "POST / HTTP/1.1" 302 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /home HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/css/bootstrap.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/css/font-awesome.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/css/dataTables.bootstrap4.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/css/select2.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/css/bootstrap-datetimepicker.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/css/style2.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/jquery-3.2.1.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/popper.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/jquery.dataTables.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/dataTables.bootstrap4.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/jquery.slimscroll.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/select2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/moment.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/img/user.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/fonts/fontawesome-webfont3e6e.html?v=4.7.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/img/logo.png HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/bootstrap-datetimepicker.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/js/app.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/img/sent.png HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:43] "GET /static/fonts/fontawesome-webfont3e6e.woff?v=4.7.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:48] "GET /fetchPatientParams/116377373 HTTP/1.1" 200 -
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.2.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/dhanasekar.m/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/css/font-awesome.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/css/dataTables.bootstrap4.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/css/select2.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/css/bootstrap-datetimepicker.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/css/style2.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/img/user.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:50] "GET /static/img/logo.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/jquery-3.2.1.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/popper.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/bootstrap.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/jquery.dataTables.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/dataTables.bootstrap4.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/jquery.slimscroll.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/images/CAD.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/select2.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/images/COPD.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/images/No%20Risk.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/img/male.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/images/CKD.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/images/hypertension.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/moment.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/bootstrap-datetimepicker.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/js/app.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/images/diabetes.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [14/Apr/2023 19:38:51] "GET /static/img/sent.png HTTP/1.1" 304 -
