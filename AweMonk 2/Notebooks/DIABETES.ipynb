# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import seaborn as sns

# %% [markdown]
# ## Data Processing

# %%
#Reading the CSV file
df=pd.read_csv('Data.csv')
df.head()
# Out:
#    Unnamed: 0  desy_sort_key gender_id  Diabetes  COPD  CKD  PVD  CAD  \
# 0           0      118683983         F         0     0    0    0    0
# 1           1      130289775         F         1     0    0    0    0
# 2           2      108632239         F         0     0    0    0    0
# 3           3      117485425         M         0     0    0    0    0
# 4           4      129416237         F         0     0    0    0    0
#
#    HyperTension  DiseaseType  ...  Total_Cholesterol Triglycerides  \
# 0             1            2  ...         226.513751     60.829092
# 1             0            1  ...         212.915038     53.870125
# 2             1            2  ...         134.289605     57.523097
# 3             1            2  ...         255.366937     57.523097
# 4             1            2  ...         160.118262     31.185296
#
#   COPDAssesstmet_Test      nMRC  FEV1/FVC_Ratio       FEV1  serum_creatinine  \
# 0            2.350348  0.684115        0.717862  90.379252          0.998853
# 1            6.964980  0.296683        0.877135  88.370560          1.025898
# 2            5.643176  0.337167        0.994377  88.580960          0.986728
# 3            1.840118  0.521873        0.717862  89.812122          0.992347
# 4            1.316497  0.326116        0.748167  89.308165          0.965424
#
#           gfr  blood_urea_nitrogen  Albumin_to_creatinine_ratio
# 0  152.072711            18.470213                    13.594130
# 1  168.231390            18.302752                    13.145523
# 2  166.307136            18.422089                     6.466951
# 3  115.380030            18.207522                    14.026312
# 4  121.808089            18.561414                    13.358217
#
# [5 rows x 31 columns]

# %%
#dopping/Removing the Unnamed column from the DataFrame.
col_names = df.columns
df = df.drop(df.columns[0],axis=1)
for c in col_names:
    df = df.replace("?", np.NaN)
df = df.apply(lambda x: x.fillna(x.value_counts().index[0]))
df
# Out:
#        desy_sort_key gender_id  Diabetes  COPD  CKD  PVD  CAD  HyperTension  \
# 0          118683983         F         0     0    0    0    0             1
# 1          130289775         F         1     0    0    0    0             0
# 2          108632239         F         0     0    0    0    0             1
# 3          117485425         M         0     0    0    0    0             1
# 4          129416237         F         0     0    0    0    0             1
# ...              ...       ...       ...   ...  ...  ...  ...           ...
# 13594      130463331         F         0     0    0    0    0             1
# 13595      122447079         F         0     0    0    0    0             1
# 13596      111252359         M         0     0    0    0    0             1
# 13597      115838463         F         0     0    0    0    0             0
# 13598      124314165         F         0     0    0    0    0             0
#
#        DiseaseType  Age  ... Total_Cholesterol Triglycerides  \
# 0                2   39  ...        226.513751     60.829092
# 1                1   55  ...        212.915038     53.870125
# 2                2   65  ...        134.289605     57.523097
# 3                2   45  ...        255.366937     57.523097
# 4                2   49  ...        160.118262     31.185296
# ...            ...  ...  ...               ...           ...
# 13594            2   63  ...        209.861854     75.989096
# 13595            2   63  ...        222.466384     57.523097
# 13596            2   68  ...        136.684044     46.968360
# 13597            7   35  ...        191.077492     83.970935
# 13598            7   42  ...        226.038146     36.740803
#
#        COPDAssesstmet_Test      nMRC  FEV1/FVC_Ratio       FEV1  \
# 0                 2.350348  0.684115        0.717862  90.379252
# 1                 6.964980  0.296683        0.877135  88.370560
# 2                 5.643176  0.337167        0.994377  88.580960
# 3                 1.840118  0.521873        0.717862  89.812122
# 4                 1.316497  0.326116        0.748167  89.308165
# ...                    ...       ...             ...        ...
# 13594             4.910732  0.309312        0.926722  88.345341
# 13595             3.998451  0.311538        0.994377  90.272900
# 13596             5.791770  0.019826        0.717862  88.156215
# 13597             0.839396  0.356834        0.846148  90.874810
# 13598             0.839396  0.287785        0.756235  90.668263
#
#        serum_creatinine         gfr  blood_urea_nitrogen  \
# 0              0.998853  152.072711            18.470213
# 1              1.025898  168.231390            18.302752
# 2              0.986728  166.307136            18.422089
# 3              0.992347  115.380030            18.207522
# 4              0.965424  121.808089            18.561414
# ...                 ...         ...                  ...
# 13594          0.992298  163.534873            18.825341
# 13595          0.974632  113.836186            18.501758
# 13596          0.999017  166.307136            18.566059
# 13597          0.957968  138.261027            18.381755
# 13598          0.953923  121.621386            18.501437
#
#        Albumin_to_creatinine_ratio
# 0                        13.594130
# 1                        13.145523
# 2                         6.466951
# 3                        14.026312
# 4                        13.358217
# ...                            ...
# 13594                    18.193768
# 13595                    14.946505
# 13596                     8.956338
# 13597                     9.482867
# 13598                    11.508743
#
# [13599 rows x 30 columns]

# %%
print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (13599, 30)

# %%
df=df.drop(columns=['desy_sort_key','gender_id','DiseaseType','race','Treated'],axis=1)

# %%
df
# Out:
#        Diabetes  COPD  CKD  PVD  CAD  HyperTension  Age  Hemoglobin_A1C  \
# 0             0     0    0    0    0             1   39        5.424227
# 1             1     0    0    0    0             0   55       10.638850
# 2             0     0    0    0    0             1   65        5.173542
# 3             0     0    0    0    0             1   45        5.009073
# 4             0     0    0    0    0             1   49        5.152320
# ...         ...   ...  ...  ...  ...           ...  ...             ...
# 13594         0     0    0    0    0             1   63        5.487710
# 13595         0     0    0    0    0             1   63        5.158783
# 13596         0     0    0    0    0             1   68        5.023969
# 13597         0     0    0    0    0             0   35        5.176758
# 13598         0     0    0    0    0             0   42        5.322452
#
#        Random_Glucose  Fasting_Glucose  ...  Total_Cholesterol  Triglycerides  \
# 0          139.418184        83.405258  ...         226.513751      60.829092
# 1          311.354333       234.105530  ...         212.915038      53.870125
# 2          139.553267        87.066844  ...         134.289605      57.523097
# 3          131.692556        78.450297  ...         255.366937      57.523097
# 4          126.881606        98.547996  ...         160.118262      31.185296
# ...               ...              ...  ...                ...            ...
# 13594      145.306845        84.743306  ...         209.861854      75.989096
# 13595      136.683426        89.887506  ...         222.466384      57.523097
# 13596      137.986204        81.360494  ...         136.684044      46.968360
# 13597      135.699074        81.554537  ...         191.077492      83.970935
# 13598      133.603212       108.348328  ...         226.038146      36.740803
#
#        COPDAssesstmet_Test      nMRC  FEV1/FVC_Ratio       FEV1  \
# 0                 2.350348  0.684115        0.717862  90.379252
# 1                 6.964980  0.296683        0.877135  88.370560
# 2                 5.643176  0.337167        0.994377  88.580960
# 3                 1.840118  0.521873        0.717862  89.812122
# 4                 1.316497  0.326116        0.748167  89.308165
# ...                    ...       ...             ...        ...
# 13594             4.910732  0.309312        0.926722  88.345341
# 13595             3.998451  0.311538        0.994377  90.272900
# 13596             5.791770  0.019826        0.717862  88.156215
# 13597             0.839396  0.356834        0.846148  90.874810
# 13598             0.839396  0.287785        0.756235  90.668263
#
#        serum_creatinine         gfr  blood_urea_nitrogen  \
# 0              0.998853  152.072711            18.470213
# 1              1.025898  168.231390            18.302752
# 2              0.986728  166.307136            18.422089
# 3              0.992347  115.380030            18.207522
# 4              0.965424  121.808089            18.561414
# ...                 ...         ...                  ...
# 13594          0.992298  163.534873            18.825341
# 13595          0.974632  113.836186            18.501758
# 13596          0.999017  166.307136            18.566059
# 13597          0.957968  138.261027            18.381755
# 13598          0.953923  121.621386            18.501437
#
#        Albumin_to_creatinine_ratio
# 0                        13.594130
# 1                        13.145523
# 2                         6.466951
# 3                        14.026312
# 4                        13.358217
# ...                            ...
# 13594                    18.193768
# 13595                    14.946505
# 13596                     8.956338
# 13597                     9.482867
# 13598                    11.508743
#
# [13599 rows x 25 columns]

# %%
#getting the information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13599 entries, 0 to 13598
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Diabetes                     13599 non-null  int64
#  1   COPD                         13599 non-null  int64
#  2   CKD                          13599 non-null  int64
#  3   PVD                          13599 non-null  int64
#  4   CAD                          13599 non-null  int64
#  5   HyperTension                 13599 non-null  int64
#  6   Age                          13599 non-null  int64
#  7   Hemoglobin_A1C               13599 non-null  float64
#  8   Random_Glucose               13599 non-null  float64
#  9   Fasting_Glucose              13599 non-null  float64
#  10  BMI                          13599 non-null  float64
#  11  Systolic_BP                  13599 non-null  float64
#  12  Diastolic_BP                 13599 non-null  float64
#  13  HDL_C                        13599 non-null  float64
#  14  LDL_C                        13599 non-null  float64
#  15  Total_Cholesterol            13599 non-null  float64
#  16  Triglycerides                13599 non-null  float64
#  17  COPDAssesstmet_Test          13599 non-null  float64
#  18  nMRC                         13599 non-null  float64
#  19  FEV1/FVC_Ratio               13599 non-null  float64
#  20  FEV1                         13599 non-null  float64
#  21  serum_creatinine             13599 non-null  float64
#  22  gfr                          13599 non-null  float64
#  23  blood_urea_nitrogen          13599 non-null  float64
#  24  Albumin_to_creatinine_ratio  13599 non-null  float64
# dtypes: float64(18), int64(7)
# memory usage: 2.6 MB

# %%
#Checking if any missing value in the dataframe
df.isnull().sum()
# Out:
# Diabetes                       0
# COPD                           0
# CKD                            0
# PVD                            0
# CAD                            0
# HyperTension                   0
# Age                            0
# Hemoglobin_A1C                 0
# Random_Glucose                 0
# Fasting_Glucose                0
# BMI                            0
# Systolic_BP                    0
# Diastolic_BP                   0
# HDL_C                          0
# LDL_C                          0
# Total_Cholesterol              0
# Triglycerides                  0
# COPDAssesstmet_Test            0
# nMRC                           0
# FEV1/FVC_Ratio                 0
# FEV1                           0
# serum_creatinine               0
# gfr                            0
# blood_urea_nitrogen            0
# Albumin_to_creatinine_ratio    0
# dtype: int64

# %%
#statistical measure about the data
df.describe()
# Out:
#            Diabetes          COPD           CKD           PVD           CAD  \
# count  13599.000000  13599.000000  13599.000000  13599.000000  13599.000000
# mean       0.033164      0.081403      0.060372      0.005736      0.034708
# std        0.179072      0.273463      0.238184      0.075520      0.183047
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        HyperTension           Age  Hemoglobin_A1C  Random_Glucose  \
# count  13599.000000  13599.000000    13599.000000    13599.000000
# mean       0.523862     56.766453        5.197939      133.338809
# std        0.499449     16.353595        0.556971       16.301535
# min        0.000000     25.000000        4.009600      109.873256
# 25%        0.000000     45.000000        4.959152      127.837873
# 50%        1.000000     57.000000        5.155112      132.136178
# 75%        1.000000     70.000000        5.364500      136.382638
# max        1.000000     85.000000       11.533923      325.866227
#
#        Fasting_Glucose  ...  Total_Cholesterol  Triglycerides  \
# count     13599.000000  ...       13599.000000   13599.000000
# mean         92.347548  ...         191.331951      64.102900
# std          15.803241  ...          43.788761      27.646785
# min          72.013652  ...         100.083243      20.016576
# 25%          84.088067  ...         157.135280      57.523097
# 50%          91.260195  ...         191.391267      63.827040
# 75%          99.198341  ...         223.696462      69.436327
# max         274.731917  ...         290.194777     296.227238
#
#        COPDAssesstmet_Test          nMRC  FEV1/FVC_Ratio          FEV1  \
# count         13599.000000  13599.000000    13599.000000  13599.000000
# mean              5.482397      0.642758        0.860364     88.315721
# std               5.224630      0.563984        0.180649      6.198480
# min               0.000575      0.000061        0.000011     50.451565
# 25%               2.225297      0.362378        0.748167     89.156330
# 50%               4.910732      0.521668        0.846148     89.893511
# 75%               7.255807      0.697954        0.959523     90.554378
# max              39.563789      3.985624        1.447107     93.261864
#
#        serum_creatinine           gfr  blood_urea_nitrogen  \
# count      13599.000000  13599.000000         13599.000000
# mean           1.125293    129.769026            19.138879
# std            0.659812     29.935943             3.971317
# min            0.910218     18.905459             4.355299
# 25%            0.980277    112.563991            18.346122
# 50%            0.996609    132.715226            18.512046
# 75%            1.014713    153.061604            18.682373
# max            6.492862    179.980299            35.356934
#
#        Albumin_to_creatinine_ratio
# count                 13599.000000
# mean                     22.344230
# std                      36.446322
# min                       0.010374
# 25%                      11.519935
# 50%                      15.401780
# 75%                      19.603653
# max                     309.876770
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# A categorical variable creation process is performed according to the value.
def Classlevel(row):
    if ((row["Hemoglobin_A1C"] >= 6.5) and (row["Fasting_Glucose"] >= 126) and (row["Random_Glucose"] >= 200)):
        return "Critical"
    elif ((row["Hemoglobin_A1C"] >= 5.7 and row["Hemoglobin_A1C"] <= 6.4) and (row["Fasting_Glucose"] >= 100 and row["Fasting_Glucose"] <= 125) ):
        return "Early on set"
    else:
        return "No Risk"

# %%
# The operation performed was added to the dataframe.
df = df.assign(ClassLevel=df.apply(Classlevel, axis=1))

df
# Out:
#        Diabetes  COPD  CKD  PVD  CAD  HyperTension  Age  Hemoglobin_A1C  \
# 0             0     0    0    0    0             1   39        5.424227
# 1             1     0    0    0    0             0   55       10.638850
# 2             0     0    0    0    0             1   65        5.173542
# 3             0     0    0    0    0             1   45        5.009073
# 4             0     0    0    0    0             1   49        5.152320
# ...         ...   ...  ...  ...  ...           ...  ...             ...
# 13594         0     0    0    0    0             1   63        5.487710
# 13595         0     0    0    0    0             1   63        5.158783
# 13596         0     0    0    0    0             1   68        5.023969
# 13597         0     0    0    0    0             0   35        5.176758
# 13598         0     0    0    0    0             0   42        5.322452
#
#        Random_Glucose  Fasting_Glucose  ...  Triglycerides  \
# 0          139.418184        83.405258  ...      60.829092
# 1          311.354333       234.105530  ...      53.870125
# 2          139.553267        87.066844  ...      57.523097
# 3          131.692556        78.450297  ...      57.523097
# 4          126.881606        98.547996  ...      31.185296
# ...               ...              ...  ...            ...
# 13594      145.306845        84.743306  ...      75.989096
# 13595      136.683426        89.887506  ...      57.523097
# 13596      137.986204        81.360494  ...      46.968360
# 13597      135.699074        81.554537  ...      83.970935
# 13598      133.603212       108.348328  ...      36.740803
#
#        COPDAssesstmet_Test      nMRC  FEV1/FVC_Ratio       FEV1  \
# 0                 2.350348  0.684115        0.717862  90.379252
# 1                 6.964980  0.296683        0.877135  88.370560
# 2                 5.643176  0.337167        0.994377  88.580960
# 3                 1.840118  0.521873        0.717862  89.812122
# 4                 1.316497  0.326116        0.748167  89.308165
# ...                    ...       ...             ...        ...
# 13594             4.910732  0.309312        0.926722  88.345341
# 13595             3.998451  0.311538        0.994377  90.272900
# 13596             5.791770  0.019826        0.717862  88.156215
# 13597             0.839396  0.356834        0.846148  90.874810
# 13598             0.839396  0.287785        0.756235  90.668263
#
#        serum_creatinine         gfr  blood_urea_nitrogen  \
# 0              0.998853  152.072711            18.470213
# 1              1.025898  168.231390            18.302752
# 2              0.986728  166.307136            18.422089
# 3              0.992347  115.380030            18.207522
# 4              0.965424  121.808089            18.561414
# ...                 ...         ...                  ...
# 13594          0.992298  163.534873            18.825341
# 13595          0.974632  113.836186            18.501758
# 13596          0.999017  166.307136            18.566059
# 13597          0.957968  138.261027            18.381755
# 13598          0.953923  121.621386            18.501437
#
#        Albumin_to_creatinine_ratio  ClassLevel
# 0                        13.594130     No Risk
# 1                        13.145523    Critical
# 2                         6.466951     No Risk
# 3                        14.026312     No Risk
# 4                        13.358217     No Risk
# ...                            ...         ...
# 13594                    18.193768     No Risk
# 13595                    14.946505     No Risk
# 13596                     8.956338     No Risk
# 13597                     9.482867     No Risk
# 13598                    11.508743     No Risk
#
# [13599 rows x 26 columns]

# %%
df['ClassLevel'].value_counts()
# Out:
# No Risk         13204
# Early on set      298
# Critical           97
# Name: ClassLevel, dtype: int64

# %% [markdown]
# ## Label Encoding

# %%
# Importing LabelEncoder from Sklearn
# library from preprocessing Module.
from sklearn.preprocessing import LabelEncoder
 
# Creating a instance of label Encoder.
le = LabelEncoder()
 
# Using .fit_transform function to fit label
# encoder and return encoded label
label = le.fit_transform(df['ClassLevel'])
 
# printing label
label
# Out:
# array([2, 0, 2, ..., 2, 2, 2])

# %%
# removing the column 'Purchased' from df
# as it is of no use now.
df.drop("ClassLevel", axis=1, inplace=True)
 
# Appending the array to our dataFrame
# with column name 'Purchased'
df["ClassLevel"] = label
 
# printing Dataframe
df
# Out:
#        Diabetes  COPD  CKD  PVD  CAD  HyperTension  Age  Hemoglobin_A1C  \
# 0             0     0    0    0    0             1   39        5.424227
# 1             1     0    0    0    0             0   55       10.638850
# 2             0     0    0    0    0             1   65        5.173542
# 3             0     0    0    0    0             1   45        5.009073
# 4             0     0    0    0    0             1   49        5.152320
# ...         ...   ...  ...  ...  ...           ...  ...             ...
# 13594         0     0    0    0    0             1   63        5.487710
# 13595         0     0    0    0    0             1   63        5.158783
# 13596         0     0    0    0    0             1   68        5.023969
# 13597         0     0    0    0    0             0   35        5.176758
# 13598         0     0    0    0    0             0   42        5.322452
#
#        Random_Glucose  Fasting_Glucose  ...  Triglycerides  \
# 0          139.418184        83.405258  ...      60.829092
# 1          311.354333       234.105530  ...      53.870125
# 2          139.553267        87.066844  ...      57.523097
# 3          131.692556        78.450297  ...      57.523097
# 4          126.881606        98.547996  ...      31.185296
# ...               ...              ...  ...            ...
# 13594      145.306845        84.743306  ...      75.989096
# 13595      136.683426        89.887506  ...      57.523097
# 13596      137.986204        81.360494  ...      46.968360
# 13597      135.699074        81.554537  ...      83.970935
# 13598      133.603212       108.348328  ...      36.740803
#
#        COPDAssesstmet_Test      nMRC  FEV1/FVC_Ratio       FEV1  \
# 0                 2.350348  0.684115        0.717862  90.379252
# 1                 6.964980  0.296683        0.877135  88.370560
# 2                 5.643176  0.337167        0.994377  88.580960
# 3                 1.840118  0.521873        0.717862  89.812122
# 4                 1.316497  0.326116        0.748167  89.308165
# ...                    ...       ...             ...        ...
# 13594             4.910732  0.309312        0.926722  88.345341
# 13595             3.998451  0.311538        0.994377  90.272900
# 13596             5.791770  0.019826        0.717862  88.156215
# 13597             0.839396  0.356834        0.846148  90.874810
# 13598             0.839396  0.287785        0.756235  90.668263
#
#        serum_creatinine         gfr  blood_urea_nitrogen  \
# 0              0.998853  152.072711            18.470213
# 1              1.025898  168.231390            18.302752
# 2              0.986728  166.307136            18.422089
# 3              0.992347  115.380030            18.207522
# 4              0.965424  121.808089            18.561414
# ...                 ...         ...                  ...
# 13594          0.992298  163.534873            18.825341
# 13595          0.974632  113.836186            18.501758
# 13596          0.999017  166.307136            18.566059
# 13597          0.957968  138.261027            18.381755
# 13598          0.953923  121.621386            18.501437
#
#        Albumin_to_creatinine_ratio  ClassLevel
# 0                        13.594130           2
# 1                        13.145523           0
# 2                         6.466951           2
# 3                        14.026312           2
# 4                        13.358217           2
# ...                            ...         ...
# 13594                    18.193768           2
# 13595                    14.946505           2
# 13596                     8.956338           2
# 13597                     9.482867           2
# 13598                    11.508743           2
#
# [13599 rows x 26 columns]

# %% [markdown]
# ## 2 ---- No Risk 1 ------Early on set 0 ------ Critical

# %%
df['ClassLevel'].value_counts()
# Out:
# 2    13204
# 1      298
# 0       97
# Name: ClassLevel, dtype: int64

# %% [markdown]
# ## Splitting the Features and ClassLevel

# %%
X=df.drop(columns='ClassLevel',axis=1)
y=df['ClassLevel']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,stratify=y, random_state = 2)

# %%
print(X.shape,X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (13599, 25) (10879, 25) (2720, 25) (10879,) (2720,)

# %% [markdown]
# ## LR

# %%
# fitting data to model

from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# /home/chandrasekar/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# model predictions

y_pred2 = log_reg.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred2)
plt.title("Risk level prediction using Logistic Regression")
plt.xlabel("Risk level")
plt.ylabel("prediction")
# Out:
# Text(0, 0.5, 'prediction')

# %%
# accuracy score

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(accuracy_score(y_train, log_reg.predict(X_train)))

log_reg_acc = accuracy_score(y_test, log_reg.predict(X_test))
print(log_reg_acc)
# Out:
# 0.9772037871127861
# 0.9772058823529411

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred2))
# Out:
# [[  19    0    0]
#  [   0    3   57]
#  [   0    5 2636]]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred2)
class_names = [0,1,2]
fig,ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix), annot = True, cmap = 'Greens', fmt = 'g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for logistic regression to predict risk levels in Nexlab ')
plt.ylabel('Actual range')
plt.xlabel('Predicted range')
plt.show()

# %%
# classification report

print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.38      0.05      0.09        60
#            2       0.98      1.00      0.99      2641
#
#     accuracy                           0.98      2720
#    macro avg       0.78      0.68      0.69      2720
# weighted avg       0.97      0.98      0.97      2720

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# model predictions 

y_pred1 = knn.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred1)
plt.title("Risk level prediction using KNN")
plt.xlabel("Risk level")
plt.ylabel("prediction")
# Out:
# Text(0, 0.5, 'prediction')

# %%
# accuracy score

print(accuracy_score(y_train, knn.predict(X_train)))

knn_acc = accuracy_score(y_test, knn.predict(X_test))
print(knn_acc)
# Out:
# 0.9792260318043938
# 0.9768382352941176

# %%
# classification report

print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.00      0.00      0.00        60
#            2       0.98      1.00      0.99      2641
#
#     accuracy                           0.98      2720
#    macro avg       0.66      0.67      0.66      2720
# weighted avg       0.96      0.98      0.97      2720

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred1)
class_names = [0,1,2]
fig,ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix), annot = True, cmap = 'Greens', fmt = 'g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for KNN to predict risk levels in Nexlab ')
plt.ylabel('Actual range')
plt.xlabel('Predicted range')
plt.show()

# %%
# classification report

print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.00      0.00      0.00        60
#            2       0.98      1.00      0.99      2641
#
#     accuracy                           0.98      2720
#    macro avg       0.66      0.67      0.66      2720
# weighted avg       0.96      0.98      0.97      2720

# %% [markdown]
# ## RF

# %%
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion = 'entropy', max_depth = 15, max_features = 'auto', min_samples_leaf = 2, min_samples_split = 3, n_estimators = 130)
rand_clf.fit(X_train, y_train)
# Out:
# /home/chandrasekar/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(criterion='entropy', max_depth=15, max_features='auto',
#                        min_samples_leaf=2, min_samples_split=3,
#                        n_estimators=130)

# %%
y_pred = rand_clf.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.title("Risk level prediction using Random Forest")
plt.xlabel("Risk level")
plt.ylabel("prediction")
# Out:
# Text(0, 0.5, 'prediction')

# %%
import matplotlib.pyplot as pyplot

pyplot.plot(y_pred,X_test)
pyplot.axis([0, 60, 0, 60])

# Print the chart
pyplot.show()

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2720 entries, 6805 to 3246
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Diabetes                     2720 non-null   int64
#  1   COPD                         2720 non-null   int64
#  2   CKD                          2720 non-null   int64
#  3   PVD                          2720 non-null   int64
#  4   CAD                          2720 non-null   int64
#  5   HyperTension                 2720 non-null   int64
#  6   Age                          2720 non-null   int64
#  7   Hemoglobin_A1C               2720 non-null   float64
#  8   Random_Glucose               2720 non-null   float64
#  9   Fasting_Glucose              2720 non-null   float64
#  10  BMI                          2720 non-null   float64
#  11  Systolic_BP                  2720 non-null   float64
#  12  Diastolic_BP                 2720 non-null   float64
#  13  HDL_C                        2720 non-null   float64
#  14  LDL_C                        2720 non-null   float64
#  15  Total_Cholesterol            2720 non-null   float64
#  16  Triglycerides                2720 non-null   float64
#  17  COPDAssesstmet_Test          2720 non-null   float64
#  18  nMRC                         2720 non-null   float64
#  19  FEV1/FVC_Ratio               2720 non-null   float64
#  20  FEV1                         2720 non-null   float64
#  21  serum_creatinine             2720 non-null   float64
#  22  gfr                          2720 non-null   float64
#  23  blood_urea_nitrogen          2720 non-null   float64
#  24  Albumin_to_creatinine_ratio  2720 non-null   float64
# dtypes: float64(18), int64(7)
# memory usage: 552.5 KB

# %%
# accuracy score

print(accuracy_score(y_train, rand_clf.predict(X_train)))

ran_clf_acc = accuracy_score(y_test, y_pred)
print(ran_clf_acc)
# Out:
# 1.0
# 0.9996323529411765

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.98      1.00      0.99        60
#            2       1.00      1.00      1.00      2641
#
#     accuracy                           1.00      2720
#    macro avg       0.99      1.00      1.00      2720
# weighted avg       1.00      1.00      1.00      2720

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test,y_pred)
class_names = [0,1,2]
fig,ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)
sns.heatmap(pd.DataFrame(confusion_matrix), annot = True, cmap = 'Greens', fmt = 'g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for random forest to predict risk levels in Nexlab ')
plt.ylabel('Actual range')
plt.xlabel('Predicted range')
plt.show()

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.98      1.00      0.99        60
#            2       1.00      1.00      1.00      2641
#
#     accuracy                           1.00      2720
#    macro avg       0.99      1.00      1.00      2720
# weighted avg       1.00      1.00      1.00      2720

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN', 'Random Forest Classifier'],
    'Score': [100*round(log_reg_acc,4), 100*round(knn_acc,4), 100*round(ran_clf_acc,4)]
})
models.sort_values(by = 'Score', ascending = False)
# Out:
#                       Model  Score
# 2  Random Forest Classifier  99.96
# 0       Logistic Regression  97.72
# 1                       KNN  97.68

# %% [markdown]
# ## Prediction Graph Of Three Models And Saving the Prediction Graph

# %%
import matplotlib.pyplot as plt1
plt1.scatter(y_test,y_pred)
plt1.scatter(y_test,y_pred1)
plt1.plot(y_test,y_pred2)
plt1.title("Risk level prediction for all three models")
plt1.xlabel("Risk level")
plt1.ylabel("prediction")
plt1.legend(('RF', 'KNN', 'LR'))
plt1.savefig("static/images/diabetesprediction.png")

# %%
import pickle
filename="diabetes.pkl"
model = rand_clf
f= open(filename,'wb')
pickle.dump(model, f)
